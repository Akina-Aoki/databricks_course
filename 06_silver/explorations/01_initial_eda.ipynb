-- %% [markdown]
-- # EDA on Supply Chain

-- %%
%sql
-- List the Volume
LIST '/Volumes/supply_chain_demo/default/raw'

-- %%
%python
# TODO: list the volume
VOLUME_PATH = "/Volumes/supply_chain_demo/default/raw"

spark.sql(f"LIST '{VOLUME_PATH}'")

-- %%
%python
spark.sql(f"LIST '{VOLUME_PATH}/data'").display()
